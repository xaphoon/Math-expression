# %%
import operator
import random
from pythonds.basic.stack import Stack
from collections import deque
import math

# %%
operation_type = ['O', 'F', 'V', 'C']
name_opers = ['+', '-', '*', '/', '^']
variance = ['x', 'y']
opers = {'+': operator.add, '-': operator.sub, '*':operator.mul, '/': operator.truediv, '^': operator.pow}
name_functions = ['sin', 'cos', 'tan', 'acos', 'asin', 'atan', 'exp', 'ln', 'sqrt']
functions = {'sin': math.sin, 'cos': math.cos, 'tan': math.tan, 'acos': math.acos, 'asin': math.asin, 
             'atan': math.atan, 'exp': math.exp, 'ln': math.log, 'sqrt':math.sqrt}

# %%
def rand_type(weights = [40, 40, 10, 10]):
    return random.choices(operation_type, weights)[0]

# %%
def rand_oper(weights = [40, 35, 15, 5, 5]):
    return random.choices(name_opers, weights)[0]

# %%
def rand_const(min = 1, max = 5):
    return random.randint(min, max)

# %%
def rand_var(weights = [50, 50]):
    return random.choices(variance, weights)[0]

# %%
def rand_func(weight = None):
    return random.choices(name_functions)[0]

# %%
def insert_right(self, new_node):
    if self.right == None:
        self.right = BinaryTree(new_node)
    else:
        tree = BinaryTree(new_node)
        tree.right = self.right
        self.right = tree

def insert_left(self, new_node):
    if self.left == None:
        self.left = BinaryTree(new_node)
    else:
        tree = BinaryTree(new_node)
        tree.left = self.left
        self.left = tree

# %%
class Node(object):
    def __init__(self, value, left = None, right = None):
        self.value = value
        self.left = left
        self.right = right

class BinaryTree():
    def __init__(self, value):
        self.parent = None
        self.left = None
        self.right = None
        self.value = value
        
    def __str__(self):
        return str(self.value)
        
    def get_left_child(self):
        if self.left:
            return self.left
        
    def get_right_child(self):
        if self.right:
            return self.right
        
    def set_left_child(self, tree):
        if self.left == None:
            self.left = tree
        else:
            tree.left = self.left
            self.left = tree
        
    def set_right_child(self, tree):
        if self.right == None:
            self.right = tree
        else:
            tree.right = self.right
            self.right = tree
        
    def set_node_value(self, value):
        self.value = value
        
    def get_node_value(self):
        return self.value

    def insert_right(self, new_node):
        if self.right == None:
            self.right = BinaryTree(new_node)
        else:
            self.right.value = new_node


    def insert_left(self, new_node):
        if self.left == None:
            self.left = BinaryTree(new_node)
        else:
            self.left.value = new_node
            
    def print_expression(self):
        if self.value in name_opers:
            print('(', end = '')
            self.left.print_expression()
            print(self.value, end = '')
            self.right.print_expression()
            print(')', end = '')
        elif self.value in name_functions:
            print(self.value + '(', end = '')
            self.left.print_expression()
            print(')', end = '')
        elif self.value in variance:
            print(self.value, end = '')
        elif isinstance(self.value, int):
            print(self.value, end = '')
            
    def print_tree(self, depth):
        current_level = [self]
        a = ' ' * (2 ** depth)
        while depth:
            a = a[:len(a)//2]
            next_level = list()
            for n in current_level:
                print(a + str(n.value), end = '') if n != None else print(a, end = '')
                if n == None or n.left == None:
                    next_level.append(None)
                else:
                    next_level.append(n.left)
                if n == None or n.right == None:
                    next_level.append(None)
                else:
                    next_level.append(n.right)
                current_level = next_level
            depth -= 1
            print("\n")

# %%
def generate_tree(depth):
    if depth == 1:
        if random.randint(0, 1):
            return BinaryTree(rand_const()) 
        else:
            return BinaryTree(rand_var())  
    else:
        t = rand_type()
        if t == "O":
            tree = BinaryTree(rand_oper())
            tree.set_left_child(generate_tree(depth - 1))
            tree.set_right_child(generate_tree(depth - 1))
        elif t == "F":
            tree = BinaryTree(rand_func())
            tree.set_left_child(generate_tree(depth - 1))
        elif t == "V":
            tree = BinaryTree(rand_var())
        else:
            tree = BinaryTree(rand_const())
        return tree

# %%
def build_parse_tree(expr):
    fplist = expr.split()
    pStack = Stack()
    
    tree = BinaryTree('')
    pStack.push(tree)
    current_tree = tree
    
    for i in fplist:
        if i == '(':
            pass
        elif i in variance:
            current_tree.set_node_value(i)
            if not pStack.isEmpty():
                parent = pStack.pop()
                current_tree = parent
        elif i in name_opers:
            current_tree.set_left_child(current_tree)
            current_tree.set_node_value(i)
            current_tree.insert_right('')
            pStack.push(current_tree)
            current_tree = current_tree.get_right_child()
            pStack.push(current_tree)
        elif i in name_functions:
            current_tree.set_node_value(i)
            current_tree.insert_left('')
            pStack.push(current_tree)
            current_tree = current_tree.get_left_child()
        elif i == ')':
            current_tree = pStack.pop()
        else:
            current_tree.set_node_value(int(i))
            if not pStack.isEmpty():
                parent = pStack.pop()
                current_tree = parent

    return tree

# %%
def build_parse_tree(expr):
    fplist = expr.split()
    pStack = Stack()
    
    tree = BinaryTree('')
    pStack.push(tree)
    current_tree = tree
    
    for i in fplist:
        if i == '(':
            current_tree.insert_left('')
            pStack.push(current_tree)
            current_tree = current_tree.get_left_child()
        elif i in name_opers:
            current_tree.set_node_value(i)
            current_tree.insert_right('')
            pStack.push(current_tree)
            current_tree = current_tree.get_right_child()
        elif i in name_functions:
            current_tree.set_node_value(i)
            current_tree.insert_left('')
            pStack.push(current_tree)
            current_tree = current_tree.get_left_child()            
        elif i == ')':
            current_tree = pStack.pop()
        elif i in variance:
            current_tree.set_node_value(i)
            parent = pStack.pop()
            current_tree = parent
        else:
            current_tree.set_node_value(int(i))
            parent = pStack.pop()
            current_tree = parent
    return tree

# %%
def evaluate(tree, x, y):
    left_child = tree.get_left_child()
    right_child = tree.get_right_child()

    if left_child and right_child:
        fn = opers[tree.get_node_value()]
        return fn(evaluate(left_child, x, y), evaluate(right_child, x, y))
    elif left_child:
        return functions[tree.get_node_value()](evaluate(left_child, x, y))
    else:
        num = tree.get_node_value()
        if num == 'x':
            return x
        elif num == 'y':
            return y
        else:
            return num

# %%
gt = generate_tree(50)
gt.print_expression()
# Out:
# ln(exp(asin((((sin(3)*tan(1))-ln(((asin((y+tan(x)))+x)/(4-((2+ln(4))+tan((((5*acos((((sin(((atan(((asin(acos(y))-2)-ln((cos((5+(x+((sin(cos(y))+asin(y))+5))))-5))))-x)+((cos((((((3+((sin(sin(ln(4)))+tan(cos((atan(sin(4))-ln((2-asin((((y+atan(y))*1)*ln(((ln((sqrt((sin(ln((2-exp(((x+y)-y)))))+3))-4))-atan((asin((ln((asin((exp(sqrt(y))*(y-(y-x))))-asin(atan(1))))-acos((x-((ln(1)+sin((x+x)))+(2/sin(atan(3))))))))*sin(((ln(5)-atan((((1-ln(x))+(ln(2)+sin(y)))*sin(x))))-asin(acos(((y-acos((3-5)))+2))))))))*(exp(sin(cos(ln(sqrt(tan(4))))))-((((x/y)+((3+(sqrt(((ln(x)+(x*4))+exp(4)))+x))+atan((asin(((asin(x)*asin(y))-asin(ln(5))))-sqrt((atan(ln(3))^(sin(x)+cos(y))))))))+acos((((sqrt(2)+1)-((sin(ln((2/y)))+(x*sqrt(x)))-ln((cos(sqrt(4))*(acos(x)-exp(1))))))-ln(1))))-(y-ln((((sqrt((((5-y)-(x^y))-(sin(x)^(y-y))))-(3-cos(4)))+x)-cos(sin((2-y))))))))))))))))))*(1*atan(exp(5)))))-exp(tan(((x/(exp(sin(sqrt(acos(ln(1)))))+((acos(sqrt(tan(sin(((((((ln(y)-sqrt(tan(exp((x+(tan(x)^exp(y)))))))-((asin(2)-exp(((4-x)-((y+sin(5))+3))))-((atan((((x-y)+(1+x))+(2*sin(y))))-(4/tan(ln(x))))/x)))*(4+(2*(y+y))))+atan(((x+(cos(sin(ln(tan(acos(5)))))^sqrt(((asin(atan(3))+((y+1)*2))*y))))+((sqrt((atan(sqrt(tan(x)))+sqrt(sin(y))))+tan(((4+(ln(1)-atan(3)))+((sqrt(y)*cos(4))*3))))^((1+acos((5+sqrt(sqrt(2)))))+(((cos((1-2))*tan(sqrt(x)))-ln(cos(5)))/(asin(4)*(2+1))))))))+sqrt(2))*(sqrt((tan((5*((exp((sqrt((5+x))+x))+(cos(((x+2)-x))+(cos(acos(2))+(y-tan(y)))))-y)))+cos(ln(y))))*tan((exp(ln(atan(exp(1))))-(4-tan((((exp((y+(x/y)))+asin(atan((x+1))))-((exp((4+2))+((x+x)-y))+(5+acos((x*x)))))*5)))))))))))-2)+tan((y-5)))))-(cos(2)*(tan(atan(atan(y)))-cos((cos(((exp(ln(ln(acos(acos((exp(ln(exp(((1+(5+(5+1)))*4))))+cos((cos((atan(((x+5)-(2-x)))-(tan((x-y))+(3-cos(4)))))/(tan(asin(sqrt((1+x))))-ln((((x-3)-(5-5))+sqrt((1-4)))))))))))))-x)*sqrt(acos((cos(y)-((atan(4)/(2-acos(y)))-(tan(x)+sqrt(cos((atan((((tan(atan(4))-sin((x*1)))-asin((3*y)))+(tan((acos(y)+4))-sin(y))))-3))))))))))+(asin((1+((1-(tan((acos(y)+sin((asin(asin(1))*(acos(sqrt(ln(tan(ln(y)))))+y)))))-((atan(exp(acos(exp(5))))-(x+atan(y)))+x)))-(asin((asin(((y-1)+(ln((acos((((5*2)-y)-asin((x+y))))*((sin(x)-tan((4+1)))-asin(cos(3)))))-(y-exp(sqrt((exp((2/x))+(exp(2)+(x-4)))))))))+((tan(1)-cos(1))*x)))+cos(((ln((cos((cos(y)-3))*(y-2)))+(3-2))-(4/asin((ln(exp(y))-sin((sin(acos(((4-x)+atan(x))))+((exp(cos(5))-y)^y))))))))))))-(tan(exp(exp((3*(((y/(exp(x)-x))*(4+acos(sin(y))))*sin(sqrt((acos(((1+(5*(atan(2)*cos(2))))*x))+(atan(((((3+x)-acos(5))+(x+(5/x)))+(asin(y)*4)))+sin(tan(5)))))))))))*((2+tan(y))-sqrt(acos(ln((atan(sqrt(y))+((acos(cos(y))+(tan(((2*cos(exp(1)))^x))-((cos(1)+((y-sqrt((x*1)))-(((4-x)-(3+y))+atan(asin(x)))))^ln((cos(asin(acos(3)))*(sqrt((2+4))*sin(sin(y))))))))/(cos(acos((4-atan(5))))-sin(asin(atan(acos(y)))))))))))))))))))))+(tan(sin(1))+(atan(tan(sqrt((((asin(5)-cos((2*ln(y))))/tan(asin(asin(((1+ln((((ln((atan(atan((5-sqrt(asin((x*3))))))^(2+2)))-exp(cos((x^atan(acos((tan(tan(y))-asin((x/1)))))))))-(asin(2)^cos(sin(sqrt(acos(cos(tan(exp(2)))))))))+cos(asin(((asin(((x+((y-(x-4))+cos((y*5))))-asin(((asin(5)+5)+atan(sin(4))))))-asin(exp(sin(acos(sin(tan(4)))))))-sin((1+((2-tan(x))+acos((tan(asin(x))*x)))))))))))+((ln(acos(sin(sqrt(1))))-exp(((((sqrt((sin(((y^(y+x))-(2*(y-x))))-exp(y)))+asin(x))+(tan(atan(asin((cos(sqrt(2))-3))))*((x+cos(5))*exp(exp(sin(atan(acos(5))))))))-(ln(3)-sqrt((ln((((exp(4)+(5+y))+(tan(5)/sqrt(4)))-1))-x))))+(exp((cos((x+ln(cos(tan(ln(2))))))+ln(tan(exp(y)))))+(4-(acos(y)+sqrt((tan(ln(1))/acos((exp((3+x))-((y-4)*(3+y))))))))))))-y))))))+y))))+ln((acos(atan(((asin(asin(4))-((cos(exp((4*cos(5))))+sin(3))+(asin(tan(tan(sin((((acos((tan(((tan(cos(4))*(x^tan(5)))+(2+(1+(y*x)))))+2))+(2-((ln(4)+(sin(sin(2))+(((2*x)-(y-y))-sin(sqrt(y)))))+acos(cos(cos(((y*4)-(4+4))))))))+(((((sqrt(x)+((sqrt(y)*x)-(exp(y)+(1-2))))-3)-tan(cos((tan(5)+cos(4)))))+(asin(((atan(ln(5))*y)+(ln((y-y))^((y-1)*ln(y)))))+(((ln((y+4))-((5-x)-(y^2)))*atan(((5-4)+x)))*sin(sqrt(((x+5)-exp(x)))))))*5))^x)))))+acos(exp(asin ...
# )))-4))/((((((sin(2)+atan(x))+x)-3)-acos(tan(3)))-(atan((((y+y)+sin(5))/((x+4)-sqrt(3))))-cos(y)))+5))))))+sqrt((acos(ln((2+(sin(x)+acos(acos(ln(sin(ln(5)))))))))-cos((3-asin(((asin(asin((tan(2)*sin((3-y)))))+cos((y*(((y/x)-x)+sqrt((x+y))))))+((x-x)*((atan((ln(3)-exp(1)))*(y-1))+2)))))))))+asin(sin((cos(x)+x))))))-(ln(((2+(3/y))*asin((((((acos((ln(tan((acos((4+y))+(sqrt(1)+sqrt(x)))))+tan((1/ln(((1/x)+asin(x)))))))-asin((sin(sqrt((((y+3)-(4-5))*(sqrt(x)+sqrt(2)))))-(acos(sin(((3+1)^2)))-asin(1)))))-acos(((x-(y*(sqrt(x)-(x/acos(sqrt(x))))))*atan(sqrt(exp((x+((3-1)-ln(y)))))))))*3)-2)+(((y+acos(atan(exp(atan((3*x))))))-exp(ln(cos(5))))/asin(x))))))+((cos(4)-sqrt((1-exp(4))))+(atan((((asin((tan((x+1))+y))*(ln(sqrt(acos(acos(5))))+((y-((((y-cos(sin(y)))-tan(3))+asin(cos((sin(x)-(5*y)))))-cos(atan(1))))-ln(exp(acos(atan((acos((y*y))-cos(tan(3))))))))))+4)-((((((asin(asin((tan((4+y))+asin(y))))*(asin((1+sqrt((y-y))))^((2^(cos(2)*tan(1)))-tan(((5-y)-sin(1))))))*asin(y))+(acos(tan(asin(y)))-(atan(asin(acos(exp(ln(1)))))+cos(cos((atan((4*2))^acos(4)))))))+x)*(((((ln((((y+x)*exp(x))+((x-2)+tan(3))))+acos(x))/exp(((sin((x+x))-((1/y)-tan(3)))+sqrt((1*(y-4))))))+5)+((acos(x)/(cos((x^ln((1-3))))+(1-sin((y+y)))))+(tan(atan((sqrt(2)+asin((x-1)))))+2)))+3))+(acos(y)-(((sqrt(sin(y))+x)^cos(sqrt(ln(tan((atan((x-5))*2))))))+((acos((2-((5+x)*(tan((3-3))-asin((x+2))))))+sqrt(cos((x+sin(2)))))-((asin(sqrt(atan(((5+y)*acos(x)))))+2)+(asin(sqrt((tan(2)*(4+(1+5)))))-2))))))))+2)))))))+2)*((cos((acos(atan((sqrt((y-y))*((y-x)-y))))-(acos((x+((exp(x)-(tan(5)-3))^(atan(5)-(exp((3-(((1+(x+((exp(sqrt(exp(x)))+(exp(atan(1))+(asin(2)+cos(x))))+sin(((ln(4)*asin(y))-atan((5*x)))))))-(exp(sqrt((sin(sin((4+y)))+asin(ln(5)))))+sqrt(sin(exp(3)))))-exp(asin((1*atan((sqrt(ln(x))+x))))))))-ln(atan((y-x))))))))+(sqrt((exp(3)-cos(sqrt(acos((sqrt((exp(((atan((asin(tan(y))-((x-x)*(4+2))))+acos((cos((1/1))-((2-y)-4))))+sqrt(exp(y))))-(y+(((cos((asin(x)+1))+(sqrt((y+5))-sin((4+y))))^asin(sqrt(acos((x^3)))))^sin((sqrt(3)+sqrt(acos((x+x)))))))))+(acos(((((y-4)/atan(2))-sin(((y+((x*3)+1))+((3+y)*3))))*exp((5-(y+atan(cos((y+4))))))))-sin(x))))))))^(asin(acos(y))-sqrt(atan(exp((((cos(asin(cos(sqrt((((acos(x)+asin(3))+4)*(((y+x)-sqrt(x))+cos((3+x))))))))+((3/(sin(cos(((tan(x)*(x^x))-tan(cos(4)))))+(ln(((y*acos(x))-cos(atan(y))))/acos((ln(acos(3))+5)))))-(asin(((((acos(x)-(5-1))+(sqrt(2)+(3+y)))*sin(acos((x-2))))+sqrt(tan(((y-x)-(2+x))))))+((3+ln(cos((acos(1)*x))))-sin((sin(((2-y)+(5-y)))+atan(((y*x)^asin(1)))))))))-1)/tan(cos((sin(acos(acos(((sin(exp(y))+x)-(asin(cos(5))-cos(exp(x)))))))-x))))))))))))+(((4+2)+(((cos(((cos(((asin(ln((exp(sqrt((sin((x-4))-((3-x)+ln(1)))))+5)))/((sqrt((y*(((5*(2-x))-y)+(4-(2-y)))))-((sqrt(sin((atan(2)/ln(x))))-cos(cos(sin((y+y)))))+((((sin(y)/4)+1)^asin(((4+y)-(x+y))))+(y-x))))+exp(((3+(atan(((x+4)-tan(2)))+sqrt((acos(4)-(4-y)))))-1))))+y))*atan(exp(3)))*(x*(sin(tan((acos(sin(asin((cos(3)*((sqrt(3)*1)^atan(exp(y)))))))-4)))+cos(x)))))*((cos(x)+(4*((1*(tan(atan(1))+(1-atan(asin(acos(tan(y)))))))+ln((exp(((((sqrt((ln(5)+sqrt(3)))+(x-acos((2-x))))-ln(cos(ln(1))))-ln((3-(atan((x-2))-((x+2)-(2-2))))))-exp(atan(((sqrt((y-5))+3)-acos(5))))))+asin(ln((exp(exp(sqrt(((4+y)-(2+y)))))-acos((2+atan(((x+5)-x))))))))))))-y))+sqrt(atan((y+(1-exp((x-asin(ln(((sin(ln(((sqrt(x)-asin(x))+ln(acos(4)))))-(((atan(asin(2))*tan((3*x)))-acos(2))-asin(y)))-atan(tan(4))))))))))))-acos(x)))-(((((x-sin(sqrt((exp((((2/2)-sin(atan(y)))^(1+2)))+((exp((3*tan((cos(asin(3))-y))))+y)+((atan((sqrt(((sqrt(y)+(x+sin(y)))-3))*tan(2)))-x)+(y+((((acos(asin(sqrt(4)))-sqrt(4))+acos(sin((x-sin(x)))))*acos(3))-((cos(sin(tan(y)))-3)+asin(y))))))))))+sin((((((exp((atan((x+exp(y)))*cos(atan((sin(((3-y)-(x-5)))+acos(x))))))-(y*asin(((((asin(x)+sin((y*1)))-(asin(sin(y))+(acos(y)-sqrt(x))))/((x+ln(sqrt(y)))+acos(y)))/asin((1+y))))))-cos((4-(x-x))))+1)/1)*((cos((2-tan(acos(tan(3)))))+(y*(cos((atan(sin((x-(x^5))))+sqrt(exp(((((1^x)^(x+x))-(sin(1)-(y+y)))-ln((5^5)))))))+x)))-(x*(ln(((((ln((sqrt((2*x))-sqr ...
# exp((atan(4)+y))*x))*tan(((4+1)-((asin(asin((acos(atan((y+y)))+y)))*asin(asin(((((5-y)+(1-y))*acos((y+x)))-sqrt(((y-3)-ln(x)))))))+(acos(atan(sqrt(((asin(y)+acos(3))-((y+x)+sqrt(4))))))/cos(atan(cos(x)))))))))))*y)))))+2))))-asin(exp((4+atan(exp(((exp((sqrt((tan((((x^cos(sqrt(5)))+(y-((((((atan(atan(x))+tan(acos(x)))/((acos(3)+acos(x))-((x+3)*4)))+(sqrt(5)-(exp((x-2))+3)))+cos(cos(acos(sqrt(sqrt(2))))))*2)+tan(4))))-(x-acos(x))))+sin(y)))*(((tan(((cos((sqrt((ln(cos(x))-atan(4)))-tan(((exp((exp(1)+sqrt(3)))+y)+((x*ln((x-x)))*5)))))+5)+(sqrt(3)-4)))+sin((acos(((((y-((atan((x*3))-3)+exp(acos((4+y)))))-(tan((sqrt((x+2))-((y*3)-x)))+(5-tan(5))))-(tan(cos((tan(atan(3))-((3+3)+x))))-x))*acos(((5^cos(sqrt(x)))+(((y-cos(atan(y)))+(ln(tan(y))+exp(x)))^y)))))-exp(sqrt((sin(asin((x+tan(5))))-y))))))+(y-asin(x)))-(((2/5)-sin(((sin(sin(sqrt((atan(tan(sin(cos(y))))+tan(sin(atan((2-y))))))))*asin((5+y)))+((tan(ln((x^atan((y+tan(1))))))+(acos(4)*(y+2)))+atan(sin(((y^sqrt(sin(acos((5+y)))))+3)))))))+cos(1)))))-(1-(ln(asin(((y+(((y*4)-(acos((sin(sqrt(sqrt(((5+y)*4))))-((y+((asin(y)-4)-exp(y)))+(x*(x*cos((2*y)))))))+sin((cos((y-(tan(4)+acos(3))))+(x*exp((acos((2+x))*(atan(3)/x))))))))*x))*((((y-atan((((sqrt(x)*3)+((5*cos(4))-5))*sin((((exp(x)+(y-2))*acos(5))+sin(ln(tan(x))))))))-(((y-asin((y-sin(atan(x)))))-(y-x))*atan((2-acos(acos((x+asin(atan(x)))))))))-x)*((sqrt((sqrt((atan(1)-((((4*2)/cos(y))*acos(1))+sin(((y-2)+2)))))-((acos((((y-4)*x)+sin((2*x))))*4)+y)))-sqrt(exp((asin(x)+(((((x-x)-(2*x))-sin(2))-acos(((y-3)*(x+x))))+(sqrt((sqrt(y)*(3+3)))-x))))))-sqrt(acos(sin(acos(atan((5-((1-sin(3))/(y+(1*x))))))))))))))+((exp((sin((exp(x)+(acos((((asin(((y+x)/(2*5)))-ln(2))+(3+exp(tan(acos(2)))))/sin(x)))+(cos(((atan(sin((x-2)))-(((x*2)+sqrt(x))+sqrt(1)))-((asin(acos(1))*((2+2)+(x+y)))*cos(sqrt((y+x))))))+exp(asin(((asin(4)-sqrt(x))*(((x+2)+3)+ln(x)))))))))*((y*sin(4))+1)))-(4^4))+atan((cos((((acos((x-cos((exp(sin(sqrt(1)))+(sqrt(5)-(asin(5)/exp(x)))))))+asin(2))+tan((sin((1-(sqrt(3)/tan(tan(ln(y))))))+atan(((sqrt(acos((5^5)))*tan(4))+1)))))+acos((ln(ln((exp(((y+tan(4))+exp((x/2))))+exp(exp((atan(5)+(x+5)))))))*sin((tan(4)-1))))))+tan(x)))))))+((((((ln(x)+exp(asin(tan(sin((cos((exp(x)+exp((3+sin((x+x))))))+asin((1-exp(((exp(2)+(y+x))-ln((x-y))))))))))))+(((exp(2)-(x-5))/tan(atan(((acos(acos(y))+cos(sqrt(sqrt((4+5)))))-(2-sqrt(ln(y)))))))+asin(tan((sin(sin(x))+2)))))+asin(x))-(((x-exp((y+((4-(tan((ln(5)-sin(3)))+sin(x)))+atan((5-(sin(atan(exp(exp((2+x)))))+sin((4/(x*sqrt(cos(y))))))))))))-(1-((tan((sin(1)-4))*((asin((1-acos((acos(atan(ln(x)))-tan((exp(3)+(x+x)))))))-(atan((5+(1*x)))-asin((exp(5)+cos(ln((atan(3)-tan(x))))))))-(atan((ln(tan(5))-sin(asin(((x*4)-cos(atan(x)))))))-((atan(sqrt(x))+((sqrt(tan(x))-x)*2))+5))))/y)))-ln(y)))-sin((y+cos(3))))-tan((((cos(asin(y))-((cos(sqrt(atan((sin(ln((acos(ln((x+x)))*((sqrt(y)-(4+4))-atan(y)))))+((((exp(cos(2))+4)*tan(3))*sin((tan(y)+2)))+x)))))+(atan(sqrt(y))+sin(4)))+(3-exp(atan(sqrt(cos((tan(ln(sin(ln(exp(1)))))-((1+atan(acos((4+y))))-sin((asin(ln(y))*sin(atan(3)))))))))))))-(4*((sin(((((asin(y)+tan((asin(exp(y))+((x+sqrt(x))-cos((5-2))))))-x)-(asin(sin((asin(3)+(ln((5+3))*atan(y)))))+ln(atan(3))))^((asin(((cos(((y-3)-1))*tan(5))-(2-sin(2))))+3)+(x-(sqrt(sin(4))-(5+4))))))+ln(y))+(4+asin(exp(sqrt(tan((atan(((ln(cos(5))-exp(asin(y)))*atan(atan((x-y)))))-y)))))))))/(sin(sin(1))/(exp((cos(tan(((x+(atan((sqrt(sin(cos(x)))*y))-exp(x)))+exp(5))))+((sin(ln((asin(exp((cos(sqrt(3))+(x+(2-y)))))*tan(asin(cos(4))))))-1)+((tan((((sqrt(exp(acos(4)))-ln(y))+sin(5))-x))^(x-(acos((((x/y)+(atan(1)-acos(y)))-(acos((2+x))/tan(sqrt(y)))))+((x-(x*(asin(y)-2)))+(y-tan((ln(x)-5)))))))*((sin((asin(asin(sin((x*y))))-(y-sqrt(tan(x)))))*(x-((y^acos((cos(1)+(5+4))))+atan(ln(sqrt(cos(x)))))))*((sqrt(acos(((asin(y)-exp(y))+3)))+4)+sin(((((ln(1)*2)-1)+(sqrt(x)+((5^5)-ln(y))))+sqrt(exp((y+(x+3))))))))))))+x)))))))))))))))+sqrt(tan(3)))^acos((exp(exp(x))*acos((((tan((((cos((atan(x)-cos(sin((1-((((((ln((ln((asin((tan(y)^4))*cos((tan(x)+(1+y)) ...
# ))))))-sqrt(ln(atan(acos((sqrt((3+tan(x)))^(sin((1-5))*((2-x)-(x+x)))))))))/x)-tan(acos(5)))))-(sqrt((asin(cos(exp(x)))+y))-tan(((3+sin(x))-y))))))/ln(sqrt(ln((sqrt((cos((tan((asin(y)+atan(((tan((asin(4)*(x-2)))+x)+1))))+2))+cos(((acos(atan(exp((ln((sqrt(y)+(x+5)))*sqrt((sin(x)+(1*4)))))))-(ln(asin(((((4-y)-2)/exp(asin(5)))*1)))-(((atan((x-(y-3)))-(ln(atan(y))^acos(exp(5))))+(((ln(x)+acos(x))+((2*5)+(5-y)))+x))-asin(asin(cos(((3/y)+ln(y))))))))*((((y*tan((sin(acos(2))+((x+x)/sqrt(4)))))*(1-tan(asin(acos(y)))))+(sqrt(x)*((sqrt(y)-(acos(asin(3))-ln(ln(5))))+atan(acos(5)))))^(sin(ln(atan(5)))*(((tan((cos(x)+(4-4)))-x)+(ln(exp(sin(x)))+exp((cos(4)-tan(5)))))*acos(sin(sin(cos(acos(x))))))))))))+(((y+(x-exp(atan(2))))-sin((y+4)))-atan(((exp(((asin(((3^(1-sin(2)))-x))+acos((1^acos(((y-3)-exp(1))))))*exp(((((y-(x*2))+sqrt(5))^(tan(asin(x))-sin(sqrt(y))))-y))))-cos(exp(((ln(cos((acos(5)-sin(x))))-1)+y))))+ln(asin(cos(2))))))))))))))+x)))-(y+((sin(ln((ln(acos((((sqrt(ln(((x+(5^acos(x)))*acos((ln((acos(cos(((cos(y)+(1+2))-atan((y*2)))))*2))-y)))))+atan(tan(y)))+(acos(acos(3))+(2+tan((acos(acos(asin((sqrt(tan(3))^sin((acos(cos(cos(2)))+cos((acos(2)+(2+3)))))))))+2)))))*(sqrt(atan(exp((sin((tan(cos(3))+(sqrt((x-atan(((tan(x)*(y-y))+sqrt(y)))))+5)))*2))))*ln(ln(5))))))-y)))-(1+(y+ln((exp(asin((exp(sin((sin(sqrt(cos(4)))*cos(tan(exp(atan((5+atan(((tan((1-5))+atan(atan(2)))-((y+cos(y))-(x+y))))))))))))*(sin((acos(4)+sin((acos((y+cos(cos(y))))-cos(((x*((1+((acos(y)+1)/((x+3)-(x-y))))-ln(asin(3))))/(asin(2)+y)))))))*cos(atan(4))))))*cos(sin((x-(((exp((tan(acos((sin((cos(x)-tan((tan(3)-exp(y)))))+(ln(2)-2))))+exp(sqrt(2))))*y)^tan(sin((4+x))))^((asin((acos(5)+(sin((tan((tan((x+2))*exp(((y-y)-(x+5)))))-exp(y)))-((y-(acos(ln(2))+(ln((ln(y)-exp(y)))-(asin((x+y))-1))))-(exp(y)+(tan(sin((sqrt(5)/cos(1))))^(3^((asin(y)+exp(5))+ln((y+x))))))))))+asin(((((4+1)^((5+asin(acos(5)))-((exp(cos(1))*tan(((x-y)^tan(3))))*((3-ln(tan(y)))+cos(((2+2)+(4+1)))))))+atan(((acos(atan(atan(exp(x))))*cos(ln(((4-x)+(x-x)))))^sin((tan((y*5))+y)))))+(ln(cos(2))-sqrt(sqrt((asin((4-sin(y)))+(y-x))))))))+(acos((exp(sin(sqrt(sin((sqrt(((1+x)+atan(5)))+5)))))+atan((sin(acos(y))-sqrt(atan(asin((sqrt(sqrt(x))+sqrt((x+5))))))))))+sin((((((atan((atan(cos(x))+(acos(5)+(y-y))))^asin(tan(1)))-((y^4)-atan(asin((y/(y-y))))))^((3-sin(atan(atan((x/2)))))-atan(4)))/ln((atan((2+tan(x)))*x)))+(y*sin(acos(y))))))))))))))))+tan(sin(((asin(4)+exp(y))-(exp(sin((sqrt(2)-cos(tan((1*sqrt((((((cos(3)+(x+((((5-5)*sqrt(x))-4)*y)))^x)-acos(tan(3)))+tan((tan(atan((asin(asin((4+x)))+tan(ln(sqrt(4))))))+3)))+((y+sin((ln((acos((atan(3)+(y/y)))+sin(acos(x))))+(atan((((y+5)-ln(5))^tan((x+5))))+x))))-(((asin(exp(y))-1)*cos((((acos(sin(2))+(2-sin(y)))-(cos(sin(x))+acos((2-3))))*sqrt(((sqrt(y)+(x*4))-3)))))+(x-x)))))))))))+((((y-sqrt((exp(1)+atan((tan(sin(exp(5)))+(ln(sin((3^acos(((x+acos(x))-y)))))*acos(1)))))))^asin(ln(y)))-(2+(((atan((cos((((sqrt(exp(atan(sin((2+x)))))-((asin(x)/(sin((3-y))+y))/((sin(sin(y))+((2-5)^sqrt(5)))-ln((sqrt(5)*(x-y))))))+2)-(atan(ln(sqrt((y-tan(acos(y))))))-(exp((y-(((y+2)/(x^x))+y)))+sqrt(x)))))+asin(y)))-asin(atan(ln(asin(y)))))/sin(atan(ln(((sqrt((asin(sin((5-((3+1)-asin(x)))))+(tan(((tan(2)+asin(3))+sin((x-3))))-acos(cos((sin(x)^sqrt(y)))))))+(atan(x)*(((sin(3)+(5/y))^ln(sqrt(sqrt(asin(5)))))+3)))-((((((sin(acos(y))*(asin(x)^(1-5)))*ln(sqrt((2-x))))-1)+acos(((((2-y)+exp(y))-5)*ln(((1+y)^x)))))+exp(y))-x))))))+((x/cos(exp(asin((exp((tan((sqrt(3)+1))-asin(ln((((5-1)/5)+cos(exp(y)))))))+sin((ln(sin(4))+sin(tan(3)))))))))+sqrt((asin(ln((cos(acos(exp(atan(4))))*asin((sqrt(3)+(asin((x+(exp(x)*y)))+((((y+2)+acos(y))*x)+x)))))))*((((ln((asin((((x+4)/4)+sin(x)))+sqrt((((x+y)*(3-5))+((x/x)-sin(x))))))+exp(sqrt(tan((atan((2-1))-((4+3)-(y-x)))))))+exp(atan(atan(4))))+x)+((((((sqrt(3)/(sqrt(asin(y))+sin(tan(5))))+((2+((2-x)-x))^acos(acos(ln(y)))))/(((x+x)+(atan((y+x))/sin(y)))+asin(((4+(x+1))-asin(3)))))-(ln(((y+(4-cos(y)))+((acos(x)+(3-x))*exp(exp(1)))))*tan(sqrt((exp((4+4))+tan((x-x))))))) ...
# )*5)))-(((ln(x)-((5-2)+(tan(cos(x))-(((5*tan(cos((sqrt(tan(((sin((x+4))+(x+sqrt(4)))-asin((1+sqrt(3))))))-(tan(atan((sqrt(tan(y))-y)))+(4+4))))))+(tan(5)/(atan(tan((tan(x)*(ln((ln((x+3))+(y-(1-4))))+tan(y)))))-(ln(x)*(((atan(tan(((y-4)+acos(1))))+((sqrt(y)-x)-asin((atan(1)*(1*4)))))-(x*(5*((cos(x)+2)-4))))+(tan(((acos((x-y))+((4+4)-(y+y)))+((x*(x^3))-atan(cos(5)))))+((tan((ln(3)+(5-3)))-((acos(2)-(3/4))-atan(y)))/sin(((x+3)*sqrt((5+x)))))))))))*(ln(1)+y)))))*cos(x))+((ln(ln(sqrt(((y+(((((y+((exp(y)^(3/tan(5)))-((tan(y)+sqrt(4))-(ln(y)^(1+x)))))-((exp((exp(1)*(x+4)))+(sin(acos(y))-((x+5)+(x+x))))-((asin(x)*atan(sqrt(1)))-(((y-4)+ln(3))*((y+2)-y)))))*tan((asin((((y-x)*cos(3))-(2+atan(2))))+(exp(((3+x)-(4-3)))^sin(exp(2))))))-ln(y))+tan(y)))+(((acos((1-x))+((3+(atan(ln(x))+ln((tan(sqrt(y))+((y+x)/(5+3))))))-3))*cos((y+((acos(2)+((((x+y)+1)+(sqrt(4)-(y*x)))-sin((2-(y+4)))))-2))))-x)))))/atan((cos(4)*acos((ln(x)+asin(((x*ln((exp(5)-((atan(((x+4)*(y-y)))/y)-y))))+sin((((1/(ln(sin(ln(4)))-((ln(x)+x)+x)))^acos(exp(asin((asin(4)*(1+x))))))/(sqrt(cos(((3-(y/4))-y)))-2))))))))))-(sqrt((x-2))+y)))))-(x-((cos(asin(cos(tan(((ln(2)-((sin(((cos(cos(1))*x)-(y-((((x-acos(x))+x)*acos(cos(atan(2))))+2))))/sin(tan((sin(x)+sin(y)))))^4))+sin(sqrt(3)))))))-(acos(((5*4)/2))+exp(atan((sin(ln(((ln(exp(((acos(cos(asin(1)))-((2+ln((x-x)))+ln(asin(acos(3)))))-cos(exp(x)))))-acos(cos((((2+((exp(2)+x)+((y*3)+ln(x))))*asin((cos(asin(y))-((2+x)-4))))*(x-(((atan(y)+asin(y))-atan((3-x)))/(cos(y)/(tan(x)-atan(3)))))))))+1)))-y)))))^(x*2))))+(4^(y+sqrt(y))))-atan(2)))-(x+sin(acos(ln(acos(acos((((asin(tan((sin((2-exp(tan(4))))+y)))-((ln((2+cos(x)))*(asin(4)+asin(asin(atan((acos((exp((x-exp(atan(x))))+sqrt(sin(((atan(y)*(x*x))-(2-y))))))+(((sin(2)-y)-ln(exp((tan(tan(y))/(ln(y)+3)))))/tan(3))))))))+acos((sqrt(((asin((x+(sin(y)*((tan(sqrt(tan(y)))-2)+(atan((1+(y-1)))-(atan((y/4))*(cos(1)-ln(4))))))))+asin(ln(((ln(sqrt((1+(1-y))))*acos(sqrt(((2^x)+(y+x)))))-y))))-ln(asin((sin(ln((((1*exp(y))*cos((4+x)))-ln(((3-4)-(2-2))))))*(3-((asin(((2^y)-(1-x)))+sin(2))+(3-2))))))))+2))))+((tan(acos((asin(3)-atan(((y-1)+((sin(exp(y))*((sin(((sin(3)-atan(x))+y))^ln((((x-x)^(2+x))+exp((x-x)))))+x))/sin(tan((ln(tan(5))-((tan((x-x))+atan(x))+ln((3*asin(3)))))))))))))+2)-((atan(tan(atan(acos(((((x+2)*(sin((exp((3+3))-tan(acos(1))))+y))-exp((ln(asin((asin(x)-(1*x))))-asin((asin(atan(y))+ln((y*5)))))))*(5+exp(((tan(x)-x)+5))))))))-(((tan(cos((exp(3)+(ln((atan(cos(acos(x)))+(atan(4)-atan(asin(y)))))-atan((((sqrt(5)+exp(y))*ln(sin(y)))+sin(sqrt((3+1)))))))))-exp(sin(3)))+(1-((x-x)+tan(((asin(atan(atan(atan((x-5)))))+(tan(cos(1))/((((y+5)-(x+2))*x)-atan((atan(2)^(x*1))))))+x)))))+sin(2)))*1)))+sqrt(1)))))))))))-asin(sqrt((atan(atan(atan(((acos(ln((asin(ln((((sqrt((tan(y)+x))+(1+ln((((sin(atan(atan(2)))*exp(sin((cos(exp(y))-(cos(x)+exp(y))))))/((atan(asin(asin((1+y))))*(ln(cos(3))-(((x*x)+asin(5))^((2+x)-(3-2)))))-4))-x))))+3)-x)))+y)))+ln((cos(x)+(2-(y+ln((5-(tan(asin(acos(((x-(atan((((5-sin(y))/(ln(y)-(2-x)))+(((4-2)-(y-y))-exp(y))))*ln(acos(((acos(5)-ln(x))*exp(x))))))-5))))+ln(asin((cos((4-(exp(atan((cos(1)+((x-y)^(3-y)))))/exp(sqrt(tan(acos(2)))))))-atan(cos((y+(x-sqrt(asin(3)))))))))))))))))+y))))*y)))))-ln(3)))))))))+(((ln(1)+acos(cos(tan(ln(exp((y*(asin(5)+(x-(asin((x+sqrt(ln(sin(sin((((x+sin((exp(((acos(sqrt(((2+(exp(x)*2))-ln(y))))+((3+acos(((((sin(atan((1-y)))-x)+2)^((x*((asin(4)*y)*asin(x)))-ln(((x+2)+x))))+y)))*3))-tan((atan(sqrt((sin(((((x+cos(3))-(acos(3)^asin(3)))-(sin(cos(5))+2))-exp(ln((5+x)))))-((((atan(y)+acos((5*2)))*ln((sqrt(x)-(y-1))))+(cos(3)+(asin(sqrt(x))+(sqrt(y)-5))))+sqrt(exp(y))))))*asin(y)))))+((((sqrt(((sqrt(acos(y))-(2+(atan(sqrt((5+y)))*(tan((atan(3)+(2-y)))*ln(3)))))-5))+(atan(y)-ln((cos(acos(atan((cos((4-y))/(sqrt(5)-acos(x))))))+(sin(((((y+x)+x)+ln(1))+2))/exp(((sqrt((x+5))^asin((y+5)))^((tan(3)-3)+cos((y+y))))))))))+3)-(atan(y)+asin((1*(((((1-ln(((4*3)*5)))+asin((((x-x)+atan(1))+cos(x))))+2)+tan(y))+sqrt(cos(y)))))))+acos(2)))))-sqrt(sin(acos(((ln(x)+(ln( ...
# )))+(asin((acos(y)+ln(exp(((x-1)+(5*y))))))+asin(((cos(((x+3)-(5-y)))+((acos(y)+(x+y))-((4+1)+y)))+sin(5)))))-ln(((sqrt(sqrt(4))-(((5-(x*(3+y)))-(y-4))/3))+3)))*cos((tan(atan(sqrt(4)))*(acos((exp((3+(x-y)))-asin(asin(((x/1)-(1*x))))))+sin((y+sin(sqrt(exp((5/5))))))))))+4))-(y+((exp((sqrt((sin(((x^ln(asin(y)))+x))+ln(3)))+acos(3)))-((1/(cos(exp(exp(4)))-(3+asin(acos(4)))))-y))+(2^((exp(ln(((asin((exp(y)+(x+3)))+((acos(1)+atan(y))-x))-(sqrt((x+y))/cos(1)))))-((exp((1*(acos(x)*sqrt((3+3)))))-exp((acos((1+atan(5)))+x)))+(sqrt(y)-(((y/(sin(3)*(y*x)))+4)+5))))+(((x*(2+x))-y)-3))))))))))+ln((((sqrt(atan((acos(exp(sqrt(exp(acos((acos((ln(atan(x))^x))/((asin(ln(x))/((2*1)^exp(3)))*(y-tan(asin(5))))))))))+((atan(tan(y))*sin(cos(((2+exp(tan(((y-1)*exp(4)))))*acos(x)))))/(x-sqrt(x))))))+5)+(sqrt(acos(atan(((asin(asin(cos((((4+x)-(sqrt((x*4))*y))-((atan(tan(1))-((1+1)-exp(2)))-ln(((1^3)*y)))))))*(((tan(sqrt(y))+(tan(3)-(3*2)))+(((sin(tan(asin(x)))-(((5/5)+sqrt(y))-((1+4)-(1*x))))-cos(asin(sin(tan(x)))))-((acos((5+atan(y)))^sin(asin((x+3))))+((x+((4+2)+(y+x)))+ln(5)))))-(asin((x+(atan(((3+x)-(y+x)))^(ln(exp(x))/((2+2)-(3^x))))))*((((ln((5^3))-((x*x)/ln(5)))*(y+tan(acos(x))))-tan((sqrt(cos(y))*cos((x+5)))))*asin((4*(ln(sin(x))+(ln(y)+tan(2)))))))))/1))))+exp((asin((asin(4)+sqrt(sqrt(exp(y)))))+((y^exp(y))+(4+x))))))+ln(((sin(y)*4)*((((ln(x)*(((x+(exp((ln(x)+sin(tan(ln(3)))))+(tan(sin(tan(asin(4))))-(atan(sin(y))/((y+sin(1))+tan((2-1)))))))-((1+(((((4+x)-5)^(2+(3*2)))^ln(exp((y-1))))+sqrt(x)))*(acos(acos(asin(((y-5)-sin(y)))))+(atan((x+((3-2)-cos(y))))^sin((((x/1)+asin(x))+5))))))/x))-(1-(2+((((asin(exp((2^(x-2))))-2)-sqrt((asin(asin(tan(y)))+exp((1-y)))))+(sin(2)-ln((exp((ln(4)-acos(x)))*x))))+(exp(tan(tan(2)))/sqrt((tan((y-(ln(1)+3)))+exp(y))))))))+asin(x))-tan(asin(sqrt(((y+ln(cos((y-ln((((y+y)+(5+x))+x))))))-1)))))))))))))^atan(((y+(acos((cos(((exp(sin(exp(asin(atan(asin(x))))))+asin(sin(ln((((acos((tan((5/tan(acos(1))))+tan(exp((4-(y+1))))))^asin(5))-(ln((y*atan(1)))*sqrt((asin(2)+sin((sin(atan(y))*sqrt(sqrt(x))))))))+((ln(y)-(x+((((exp(y)*atan(x))-((y+1)-(4-y)))+(atan(2)+exp(asin(5))))+ln(atan((asin(4)/atan(x)))))))-tan(((sin(cos(((2/3)-asin(x))))-sin(((acos(1)+(y+3))+(asin(x)+acos(x)))))-ln((acos(((x+1)*sqrt(y)))-sqrt((cos(2)-acos(5)))))))))))))-(asin(sqrt(1))-(sqrt(x)-((cos((sin(y)+acos(cos(3))))*1)+exp(((y^asin((exp(x)*(atan(acos((cos(y)-3)))+y))))+cos(atan(ln(x))))))))))*sqrt(atan((x+x)))))+sqrt(1)))^asin((2+(5-acos((exp(exp(((exp(cos(exp((((((y-(3+(y*x)))+exp((sqrt(y)^5)))+sin(sin(ln((x*y)))))-(2-(ln(acos(4))+ln((y-x)))))*y))))+sqrt(((3+(x+exp((tan(3)+sin(asin(y))))))+(x^(atan(atan(tan(acos(x))))+(y-x))))))+asin((cos(sqrt(((((atan(sqrt(tan(4)))+cos(sqrt(asin(5))))-sqrt(((exp(4)+acos(x))+((x-x)-5))))*1)-atan(exp(cos(acos(y)))))))-(acos((5-atan(cos(acos((x*tan(asin(x))))))))-4))))))/y))))))))))+2))/ln((3*exp(sin(sqrt(sqrt(cos((sqrt(y)+y))))))))))+2)))))))-4))))))))))-(y-(((cos(tan(x))-((asin(cos(2))+(((asin(sqrt(((sqrt(sqrt(y))+(cos((y*(ln(asin(y))+sin(cos((5-cos((ln(cos(5))-asin((3+((y-((y-((2-sin(((asin(x)*x)-sin((2-tan((asin((cos((x+ln(atan((acos(5)*sin(x))))))+sqrt(acos((((sqrt(sin(3))-((x+2)+(y/x)))*y)-tan((5*ln((4*3)))))))))-(((((4+((1+(acos(y)+y))/(ln((3+x))*(exp(x)+cos(y)))))-sqrt(exp((atan((3+x))*3))))*(x+((y+ln(atan((x+5))))+sin(3))))+ln((asin((y+(exp(sin(5))-(asin(y)+(y-5)))))*sqrt(2))))-asin(exp(((((y+cos(cos(y)))*sin(exp(cos(3))))+x)-asin(asin(((tan(x)-2)*(tan(y)-5)))))))))))))))+(asin(sqrt(ln(y)))-exp(2))))/((sin(y)-(y-tan(2)))-asin(5))))+acos((asin((((sin(sqrt(exp(cos(sin(ln(((((cos((ln(x)+(y*cos(x))))-(((asin(3)*(3/4))-(sqrt(1)-3))*((5+(1*3))+(x-(1+1)))))+(asin(3)-(sin(acos((x^y)))+((exp(x)+(4+3))+y))))-sqrt((((((x+y)*sqrt(y))^acos((y+5)))+tan(((2+x)-4)))-cos(((sqrt(5)+tan(5))+((2-y)-sqrt(1)))))))-exp((((acos(sin((x^3)))+exp(((y-4)*(x^x))))+x)^(sqrt(3)-(sin((x*(x-x)))+ln(sqrt(ln(y))))))))))))))+1)-3)+ln(x)))-2)))))))))))))+asin(ln(x))))-y)))/((asin(y)+exp((((1-1)+atan(((atan(x)+ln(3))+tan((exp(sqrt(y))+atan(atan((tan( ...
# cos(2))))+((((asin((atan((x-3))-(exp(x)-(3-1))))+(((sqrt(1)*(x/x))-ln((y-2)))/sqrt(cos(cos(y)))))/exp(exp((x+2))))-((((((5*1)+(x+1))-tan(cos(x)))+(((2+y)+atan(x))+((1-y)+(4-x))))-atan(tan((ln(y)+sqrt(x)))))+asin(y)))-atan((exp(atan(atan((asin(x)-(x*x)))))*exp((atan((4+asin(1)))+cos(x))))))))*(((tan(1)-exp(((sqrt(ln((5-sin(3))))*(x-((asin(y)-y)+atan((x-x)))))+5)))^x)+sqrt((sin(1)+(((acos(asin((cos(y)+4)))-sqrt((atan(tan(1))-(x-(1+x)))))+atan(exp((ln(ln(2))^2))))*ln(((sqrt(atan((4+3)))*atan(exp(1)))+exp((asin(2)*x))))))))))))+((acos(y)/x)-acos(((sin(sqrt((3*5)))-5)^(2^asin(ln((y*ln((((y-atan(3))+4)-atan(sqrt((4+y))))))))))))))))-cos(sqrt(atan(cos((ln(((2/cos(x))+asin(((asin(atan(sqrt((acos((((1-1)/(2+1))*ln(sin(1))))*((((4*x)+y)*asin((x-y)))-(y*sqrt((3/4))))))))-acos(acos(asin(cos(1)))))/(acos(y)+3)))))*(3-asin((atan(sqrt((((asin(tan(exp(y)))-acos(sin((sqrt((y-x))*5))))-(((x+(sqrt((2-3))-(ln(y)+(3+x))))+ln((ln(y)+((x+3)+(x+5)))))-((ln((sqrt(x)-x))+(asin(x)+(2*asin(y))))-acos((asin(sqrt(3))+cos(cos(3)))))))+1)))+x)))))))))))))))))^(((((x-exp(x))-acos((x+asin((sin(((x+(5-(sqrt(tan(x))-(y-exp(sqrt(tan(cos(x))))))))^(acos((tan((y-atan((asin(((cos((x+ln(atan((atan(tan(1))+((y*x)-(x*4)))))))+y)-1))-exp(cos((sin((sqrt((sqrt(atan(x))*(((x+y)+(x+y))-exp(cos(4)))))*exp((acos(((x+4)+cos(y)))+(5-((3-3)-sin(y)))))))/((((x*(y-sqrt((5+4))))-(((acos(y)+ln(x))+((y-4)*1))+(asin(y)+asin(asin(1)))))-2)+acos(sqrt((sin(((2^4)+cos(1)))-y)))))))))))-(cos((y*x))-(atan(exp(2))*(((((sqrt((sqrt(cos(tan(y)))+((sin(sin((3*y)))+ln(y))+y)))*((((exp(sqrt((y-x)))+1)+x)-x)-exp((((((1+2)+(4-1))*((3*x)+(y+5)))+sqrt(cos((5+y))))*((tan(y)+((1+y)-x))-tan(sin(sqrt(5))))))))+5)-4)-sqrt(cos(atan(cos(asin(asin(((tan((3-4))-ln(atan(y)))*2))))))))+x)))))-(sin((3+asin(sqrt(x))))/(y+y)))))+sin(ln((((5-(sqrt((sqrt(y)*atan(tan((2*5)))))-sqrt(sin(acos(y)))))-y)+(sin(atan(ln(x)))+cos(exp(acos(exp((tan(asin((exp(tan(acos(((((1-2)+(x+2))-y)-1))))+(acos(sin((atan((2*(4*2)))+(ln((x-y))+3))))-asin(asin((3+exp(4))))))))+((5*sqrt(((3*atan(sin(tan(ln(sin(4))))))*asin((exp(ln(tan((x-y))))*cos(sin((3^sin(x)))))))))*y)))))))))))))))+atan(x))+5)+asin((x^(cos(((asin(2)^((((ln(ln((sqrt(sqrt(cos(asin(exp(tan((1+3)))))))-((acos(tan((exp((3+(atan(y)^((cos(((5-4)-(2-5)))+(cos(x)^sqrt((x/x))))*(acos((acos(y)^(y-y)))+((tan(3)-x)+y))))))*(y-ln(x)))))+((acos(acos(acos(1)))-sin(acos((((y/(((ln(x)-x)+4)^sqrt(y)))+(acos(exp(((2-1)+exp(4))))*5))-(5-(x^((sqrt((y-1))-exp(x))-y)))))))-(4+tan((tan(sqrt(sin((sin(5)+cos(sqrt(3))))))-(exp(sin(exp(asin(cos((2+y))))))+sqrt(asin((asin(atan((5+4)))-x)))))))))+sin((exp(((((acos(y)-((exp((acos(5)+(5^y)))+ln(((y*4)+(3-2))))+ln((sin((1*1))+(exp(1)*(x-1))))))+(((acos(tan((3+1)))+(((5+y)-(1-y))-acos(exp(4))))*(sqrt(atan((5+5)))-(sqrt((3*y))-(y*(4*y)))))*exp(((acos((x^5))+(sin(3)^x))+(acos((y+3))+tan((y^3)))))))+((asin(tan((tan(1)-3)))+sqrt((2-(5+((2+x)*asin(1))))))-atan(x)))-sin(asin(1))))*(((sin(sin((atan(atan(4))/sqrt(exp(1)))))*(sin(atan(tan((tan((4-x))-cos(sin(x))))))*y))*asin(sin((cos((sin((y+(x+2)))+(3-(ln(x)-(y+3)))))*y))))+y)))))))-((y+ln((exp(exp(atan(((x^acos(((asin((acos(asin(2))+y))/(4-sin((sin(1)-(x-x)))))*sin(((((x*4)*atan(y))+atan(cos(5)))-((cos(5)-acos(1))/y))))))-acos(asin(cos((x/(asin(ln(asin(5)))+atan(((4-2)-exp(1))))))))))))-(cos(y)-(tan(4)+((tan(y)*acos(cos(atan(y))))-4))))))-atan(acos(atan(y)))))*cos(cos(1)))+asin(2))+sin((((x-atan(y))+tan(1))+((((2+exp(sqrt((5^x))))*4)^(1-((exp(ln(((ln((4*y))/((5-3)*(sqrt(sqrt(sin(atan(atan((y+y))))))-y)))+(cos((asin(sqrt(cos(ln((tan(y)-(1+3))))))-(((tan(exp(sqrt(1)))+(acos((5*1))-sqrt(asin(y))))^exp((ln((x+y))-exp(y))))*tan(x))))-((((3-(2-((acos(2)-(2+5))^((y+x)-(x+x)))))*((x-4)+(tan((y+acos(2)))-3)))+ln(((3-exp((3+sin(4))))^((acos(y)*(ln(2)+(y+1)))-sqrt(cos((y/x)))))))+(x*asin(((x-ln((exp(2)+1)))*(asin((acos(x)^3))+acos(5))))))))))-5)+((asin(y)+3)+sin((sin(5)+exp(atan(1))))))))+(((x^2)-ln((5+(cos((sqrt((atan(ln(sin((((ln(x)-(x*x))+1)-(sqrt((4^5))-(exp(y)^asin(y)))))))*acos(1)))+(cos(y)/(sin((acos((((5-(4-x))-(sqrt ...
# +((cos(x)/(asin(acos(((y-sqrt(sqrt(y)))*(sin(asin(2))+((2+x)-sqrt(5))))))-asin(sqrt((x/2)))))+sin(asin((((((ln(x)+(3+3))+3)+ln((3+acos(2))))-ln(((sin(4)*atan(5))-((x*y)+(x-y)))))+2)))))+exp(y)))*((acos(2)+((x-asin(acos(ln((((sqrt(ln(y))+(sqrt(x)/tan(2)))-(cos(tan(x))-1))*(4*ln(((x-y)-(2-x)))))))))-(atan(4)-3)))*5))))))))+ln((sin(cos(1))^3))))^tan((atan(sqrt((y-(cos(tan(sqrt(x)))*5))))+((5/ln(x))+((asin(x)/y)-((acos(ln(((asin(ln((((((ln(sqrt(5))+((ln(exp(3))-4)+sin(atan(y))))+((tan(2)^asin((sin(x)+(3+x))))*y))+((ln(2)-(y+y))*(((x+tan((y-1)))-(((5/y)-(x+x))+(4*ln(y))))-(atan((ln(y)+(4+3)))*sqrt(atan(acos(1)))))))+((sin(((y+4)+(y-((y*y)+(1-x)))))/asin(((5+5)*(asin(atan(y))-asin(acos(x))))))+2))-2)))-ln(((exp(((((cos(((y+2)-(y+x)))*cos(((4+x)+cos(x))))-asin(1))/(sqrt(asin(((x-x)-(1-3))))/acos(exp(y))))+ln((((((3+x)*(x+3))-atan(tan(y)))^(sqrt((y-x))+((y+3)+cos(x))))-atan(2)))))-(sqrt(cos((1-y)))*exp(((x+((x*((x+4)-sqrt(y)))/y))-acos(((asin((y+2))+((x^5)-(x+5)))+sqrt(((x-y)-(x+2)))))))))*exp((((exp(4)*(tan((acos(atan(x))^acos(sin(x))))+(tan(tan(atan(y)))/x)))*sin((y+((asin(cos(2))+asin(exp(x)))-atan(3)))))*((sin(1)*sqrt(x))+tan((ln(((tan(y)+(5+4))+tan((3-y))))-(ln(sin(y))+ln(exp(cos(5))))))))))))/((((exp(sqrt(ln(tan(acos(5)))))-tan(cos(sqrt(((y*((3-exp(y))-(x*tan(x))))-(ln(((x^x)+x))*2))))))+(y-tan(sqrt(((ln(y)-1)*sqrt((tan(sin(sin(x)))-sin((acos(1)-tan(x))))))))))*((((cos(exp(atan((acos((x+3))+3))))-y)-sin(exp((exp(y)+((1-(5+cos(1)))*sin(atan(atan(3))))))))+atan(4))-exp((x+(3-(5*atan(atan(cos(sin(y))))))))))+(1*ln(((((y+cos(tan((tan((3+1))+x))))+(cos(cos(exp((y+(x+y)))))-tan(exp(sqrt((sqrt(x)-tan(4)))))))+exp(((y+(exp(y)+3))*(sin(asin((sin(x)-atan(3))))+((y+4)+asin(asin(cos(1))))))))+tan((((x+y)+cos(2))-(tan((x/sin(x)))+y))))))))))-exp((2+ln((sin(((asin(tan(atan(((acos((sin(4)-(3+y)))-ln(ln(atan(5))))+(cos(y)-(((3*x)+y)-((x+y)-(y*y))))))))+((tan(x)-y)*(ln(exp(((y+((x+1)-(5+1)))*3)))-y)))^(((exp((sin((atan(sqrt(5))+((3+x)+cos(1))))-(tan(acos((x-x)))+y)))-((y*(tan(((1+y)+(x+x)))^sin((asin(x)*(x^1)))))-tan(exp(3))))+(exp((cos(sin((sqrt(5)-exp(3))))+ln(x)))+((exp((((x-5)+4)-x))+atan(5))*1)))+sqrt(2))))-sin(sqrt((5+(sin(2)-((acos(((((x*4)-x)+(acos(1)^atan(x)))+3))+x)/sqrt((exp(exp(((1+3)+(y*1))))+(4+atan(x))))))))))))))+(((asin(((((5+exp(y))-y)-cos(5))*exp((asin(5)+(ln(tan(((y-5)+1)))+sin((asin(exp(sin(ln((exp(y)+sqrt(5))))))/asin((acos((sqrt((y+x))-((y+2)-(3-3))))+(x+5))))))))))*exp(y))+(tan(sqrt(asin((cos(tan((tan((1^x))*(exp((3-sin(cos(ln(1)))))-((4-x)-5)))))-sin(x)))))+cos(5)))*x)))))))*asin(tan((atan(3)*x)))))))))))-5)))))/((x+((y+sin((((sin(1)-sin(cos(cos(exp(atan(((atan(((y*(cos(cos(x))+exp(((tan(sqrt(asin((ln((exp((atan((cos((5/sin(y)))-((x+exp(3))-exp((4*5)))))-asin(asin(ln(((5+y)-sqrt(2)))))))*acos((exp(tan(x))+(1+asin(((sin(1)-(4-y))-((5+3)+(5-4)))))))))+(acos(tan((sqrt((tan(sin(cos(1)))-ln((acos(y)-exp(y)))))+x)))-2)))))+3)-(5^sqrt(x))))))-tan(atan((x-ln(sin(x)))))))-((sqrt(sqrt((acos(atan(((((3+1)+sin(acos(((5^asin(((sin((y-sin(3)))+3)+acos(2))))+tan((acos(cos(sqrt(((5-x)+y))))+x))))))+atan(y))+atan((((sqrt(exp((cos((exp(acos(tan(x)))*5))+2)))+atan(((exp(((x-cos(y))+ln((5+(4-x)))))+(2+(cos((acos(1)-acos(4)))+(exp(sqrt(y))+sqrt((5*4))))))+(x+cos(atan(acos(asin((3-5)))))))))+y)-y)))))+x)))*((tan(tan(sin(ln(acos(y)))))^((asin((5/ln(((tan(sin(asin((sin((((y-(3-y))+tan(asin(x)))-(asin(ln(2))-(tan(y)-sin(x)))))+5))))+sin(((2*tan(sqrt((5+((2-(4/5))-(cos(y)-y))))))^y)))+(((cos(cos(tan(y)))+atan(cos(cos(4))))^(acos(x)+atan(3)))+ln(y))))))^acos((sin((exp(exp(((acos(((atan((2+(2+y)))+acos(2))/acos(sqrt(((x*y)-x)))))*(ln(((x-((4-x)+sin(2)))-exp((sin(x)*(x+x)))))-exp(sqrt(y))))+(((asin(ln(5))-((atan((y+3))+((x-y)+3))+(1+(sqrt(x)-cos(5)))))*2)+((3-(x*ln((ln(y)+sqrt(3)))))+x)))))+(tan(((((((cos((x^y))-tan(sin(x)))-atan(x))+y)+4)+(3-cos(((4+(asin(3)+tan(y)))*tan(sqrt(exp(x)))))))-((5+((cos(atan(y))+tan(((y+3)+x)))-sin(sqrt(ln(3)))))+(ln((3-((atan(5)+sin(x))-(ln(x)*1))))-asin(sin(atan(acos((x+3)))))))))-x)))+ln((sqrt((((exp(acos((exp(y)-(co ...
# ))+5)-ln(acos(y)))+((tan(sin((3-x)))-asin((ln(1)-1)))+tan((4-(asin(2)-5))))))-(ln((cos(3)^((y+(acos(3)^acos(x)))^asin((sqrt(5)*2)))))-ln((((ln((4/1))+cos((1-5)))+(sin(2)+2))*(2-((1-x)-((1*x)*(4+3))))))))*acos(sin(sin(sqrt(cos(((2-(2*1))-1))))))))))*(sqrt(((cos(ln(2))-(exp(asin(((ln((sin(y)+(5+3)))+ln(((x*x)-x)))*4)))*asin(3)))+(asin(tan(sqrt(((2-y)+tan((ln(sqrt(5))-atan(x)))))))-(((acos(acos(asin((sqrt(x)+exp(4)))))+(asin((x+(y^sqrt(x))))-(tan(cos(exp(3)))-(sin((y^4))-x))))-4)+((exp((cos(4)+y))+y)+ln(2))))))+atan(ln(tan(y))))))-((tan(exp((atan((((((tan(1)+(sqrt(5)-(tan(3)+x)))-(2+acos(y)))*sin((ln(ln(tan(x)))^((y-sin(x))+(x+(y+x))))))-(atan(sqrt(cos(((2+x)*(y-x)))))+(atan((((x*2)+exp(y))+cos(2)))/x)))/2))+tan(y))))+ln((y+y)))-x))-exp(sqrt((y*5))))-3))+ln(atan(sqrt((sin(atan((ln(asin(sin(((acos(cos(ln(cos(y))))-acos((acos(atan(y))+cos(x))))+(2*ln((((tan(3)-tan(tan(4)))-4)*2)))))))+asin(y))))+((sqrt(atan(((tan(((ln((((sin(4)-tan(1))-tan((y/y)))+((4*(y+y))+y)))+exp((tan(exp(2))*((acos(5)+y)-3))))*asin(cos(y))))-atan(asin(sin((((((y+2)+(y*4))-(atan(y)+(y+4)))+(asin(y)+(cos(3)+cos(2))))-acos(asin((5+x))))))))+((asin(ln(sin(ln(cos(y)))))+sin((x-(x-(atan(((x-4)+(1/1)))-(x+x))))))*(x-(((2-y)-sin(atan(exp((acos(2)-sin(y))))))+((y+(((y+ln(5))-tan(atan(y)))*asin(cos(cos(5)))))+tan((sqrt(ln((x-1)))*(atan(ln(1))+sin(sqrt(3))))))))))))-atan(((x*(cos(((((y/(cos(acos(y))*((x-y)+x)))-3)+sqrt(sin((((3*y)+4)+acos((y+1))))))+exp(ln(sqrt((acos(x)-(5-4)))))))+exp((sin(4)-((cos(x)*asin(asin((ln(5)/(5*y)))))*y)))))/x)))+exp(cos((x+y))))))))))))))+exp(((cos((atan(((atan((cos(2)*acos((2^(((exp(atan(ln(3)))+(sin(sqrt((sqrt((((y-(2+1))+x)-atan(((4*x)*cos(2)))))*((ln(1)+acos(tan((1*y))))-acos(y)))))+(2*exp((asin(5)-(((x-cos(cos(3)))-4)/sqrt(asin(asin(3)))))))))+sin(ln(((acos(acos(((acos((x-3))+(y-tan(y)))-(((x+y)*3)*(cos(y)-4)))))+(exp(2)*(asin((y-(asin(y)+acos(5))))+sin(((ln(2)^y)*exp(y))))))+(sqrt(acos(x))+2)))))+sqrt((atan(exp(((atan(asin(4))+((y-exp(((2+y)+sqrt(x))))-atan(tan(5))))-4)))/((exp(2)+cos((sqrt(2)+(((sqrt((x-1))+(atan(y)-cos(y)))-tan(exp(y)))*(3-x)))))-(x+(ln(atan(5))-(2*(tan(sqrt(((2+x)-x)))-asin(y)))))))))))))+((y+(cos(((cos(exp(((exp(sqrt((sin(exp(ln(y)))-((5+cos(4))+((3+x)+exp(x))))))-acos(((5^(exp((y-2))+atan((4-2))))+((((y/5)-(3+5))^sin(asin(x)))*((sin(5)/(4*4))-acos(5))))))-exp(cos(5)))))+(acos((cos(((3-(4-(atan((y-y))-(y+atan(3)))))-((cos(5)+y)+exp(1))))-exp((((((atan(y)*x)+cos((5*x)))-(((2+y)+2)+asin(x)))-(x+(y-x)))-2))))^2))+tan(((sin(ln(ln(ln(4))))*asin(acos((5*tan((acos(sqrt(2))+atan(atan(1))))))))+ln(2)))))-cos((y-y))))+(((y-(1+(tan(5)+asin(((atan(cos(x))+tan((((tan(3)*(sqrt(cos(1))-atan((x-1))))+(atan((cos(1)*(x+y)))-(4*ln(sqrt(2)))))+(y-x))))-(asin(y)-asin(ln((sqrt(cos((asin(2)*(4-4))))+y)))))))))*ln(4))+5)))+(cos((exp(atan(4))+tan(((ln((ln(3)+sin((tan((asin(tan(sin(2)))+((sin(2)/asin(ln((x+x))))*(((atan(y)+y)/sin(cos(1)))^sqrt((atan(x)-cos(4)))))))-exp(((atan(tan(tan(atan(x))))+(sin(ln(exp(3)))+sin(asin(5))))+exp(((exp((y+y))+cos(tan(y)))-x))))))))/((1+x)/(((acos(acos((x+(sin(cos(ln(y)))/1))))-((asin((atan(sqrt(exp(x)))+tan(tan((5+5)))))*exp(sqrt(atan(asin((2-1))))))-acos(1)))-x)-ln(((ln(tan(sin(acos(sqrt(x)))))-cos(tan(((exp((5*y))-sin((4+5)))-4))))^(((x-((sin(1)-(y+atan(y)))-exp(ln(sqrt(x)))))+((exp(3)-(asin(y)+((4-5)+acos(y))))-tan(acos(x))))*atan(y)))))))+(ln(tan((y-((sqrt(y)-((cos(exp(1))+sin(5))+(4+cos((((1+1)+sin(x))^((y-x)+sin(x)))))))+(x+ln(sin(tan((y-tan(sqrt(1)))))))))))+(ln(exp(ln(3)))^3))))))*ln((((sqrt(sin((((((exp((ln(3)-x))-(atan(acos(acos(sqrt(y))))+(ln((cos(1)*cos(4)))-(y+(1*cos(x))))))+((sqrt(acos(asin((1+y))))+1)+asin(((5-((5+4)-(x-x)))+tan(ln(exp(1)))))))-(asin(ln(exp(atan((x-asin(1))))))+4))-sin(((exp(1)+tan((5+(((x-1)-sqrt(x))+cos(atan(4))))))/asin(ln(sin((4+cos((3+y)))))))))-(tan((asin(((ln(((2+y)*cos(5)))/y)*(y+acos(((4^5)+(x+y))))))+(sin(4)-cos(atan(2)))))-((sin((5-tan(asin(((4+y)-ln(1))))))*(sqrt(4)+sin((asin((sqrt(x)+(x+3)))+y))))*tan(tan(asin(2))))))))-exp(asin(((cos(sqrt(y))/((((tan((sin((x*5))- ...
# (2-2))-(acos(2)*exp(4))))*y)))+tan(asin((((((y^x)-(4-y))*((5+1)+asin(4)))-x)/(exp(atan(tan(5)))+(((4-x)/3)-y))))))^4))))))+((3-5)-((asin((x-((atan(cos(y))+exp(asin((3+(asin(5)*cos(asin(exp(x))))))))+(asin((3+cos((((atan(4)-5)+((2/1)+(y+y)))+(((2+2)-1)+y)))))+(x+ln(sqrt(((exp(5)-x)-(ln((1*x))+(sqrt(4)*cos(y)))))))))))*(exp(1)/(x-sqrt(sin((x-((cos(3)+sqrt(sqrt(4)))+atan((tan(ln((y*y)))-((3^sqrt(y))+asin(acos(4))))))))))))*atan(5))))+((exp(x)*sin((sin(sqrt((x+((acos(2)+((sin((2+(sqrt(x)+(1+4))))-y)-((tan((asin(3)-x))+(tan((y+3))+ln(asin(5))))*atan(tan(y)))))+(acos(4)+((cos(ln(sqrt((3*x))))+exp(acos(y)))+tan((exp((3-(4+5)))*sin(x)))))))))-((sqrt(y)-ln(exp(((((cos(1)*(((2+4)-(3-4))-5))+2)-tan(ln(((cos(1)-atan(5))-5))))+cos((sin(((x*y)*cos((4+x))))-exp((exp(asin(1))*((3+2)-5)))))))))*(ln((sin(asin((((x*asin(tan(1)))-asin(x))+x)))+atan((asin((((ln(x)-(4+5))*(ln(y)^(x+y)))-tan((atan(x)-acos(y)))))+acos(cos(((x*acos(y))+tan(5))))))))-(((cos((atan(atan((acos(y)^(y*5))))-2))+((5+(asin(((x+4)*(y-x)))*(2*asin(4))))+(asin((sin((x+y))+asin(1)))^sin(3))))+x)-tan(3)))))))+(atan(5)+((sin(asin(exp((sin(asin(exp((((ln(5)*(y-2))-((4+x)-ln(1)))-y))))+(((acos(1)*(4-atan(((x+2)/1))))-(ln(exp(cos((3-x))))-(2-(atan(exp(4))+(ln(y)-sin(y))))))*((y-2)*((cos(cos(exp(y)))*tan(((3-x)/y)))-atan((2-acos(ln(4)))))))))))+sin(((cos(cos(cos((4+(((sqrt(x)-(5-x))^y)*x)))))-(asin(2)-((3-acos(((sin(tan(3))+y)*(ln(sin(1))+sqrt((y+x))))))^sin(asin(((atan(cos(1))-acos(5))/tan(((3^5)+tan(x)))))))))^asin(sqrt((acos(exp(exp((4/(ln(x)-cos(5))))))/(atan((sqrt(5)-acos((ln(y)-sin(3)))))-(tan((sin((y+2))+(atan(y)-(1+4))))-((cos((x-2))+sin(x))-y)))))))))-(tan(asin((((atan(2)+y)*(atan((sqrt((2/5))*1))-x))-ln(atan((sqrt(5)^tan(((sqrt(sin(2))^((x-y)+4))/(tan(x)+((4-1)+3))))))))))+(1*5)))))))+acos(((atan(acos(4))-(tan(x)+sin((asin(asin(asin((exp(sqrt(5))-sqrt(atan(sin(cos(acos(sqrt(acos(x)))))))))))-(asin(((asin(sqrt(ln(atan((tan(sin(y))+sqrt(3))))))^tan(x))-(sin(2)-(((asin(cos((x-(1+1))))+((y+ln((4*x)))+ln((acos(4)+1))))+(asin((tan((1-x))*cos(asin(x))))-1))-3))))-(asin(tan((ln(1)+(3/exp(atan((cos((y-5))-x)))))))-((atan(2)+((3+tan(((sqrt(acos(4))+y)+(cos(acos(5))*((x-y)+(2/2))))))+cos(1)))+exp((asin(exp(x))+(x*(1-(atan(((y-x)*(x-4)))-asin(sin(exp(4)))))))))))))))+(asin((((((atan((sqrt((acos(atan(((x+1)+(1-x))))-tan(acos((sin(x)+(y-5))))))-sin((3/(x-sqrt((ln(y)*ln(1))))))))-atan(exp(2)))-sqrt(acos(x)))+y)+atan(exp(x)))*exp(3)))^(1-(asin((acos(asin(((x-(((ln(((x-1)-2))*(((x+y)+x)*(2+acos(y))))+sqrt(x))-atan(((cos(sin(y))+(5*4))+acos((cos(y)*(x*1)))))))^(ln(asin((4*4)))-x))))/ln(2)))+((ln(y)*5)+tan(sin((tan(2)-tan(asin(tan(asin(y))))))))))))))))-exp(asin(cos(tan((3-sqrt((atan((acos(4)+(x+((x+5)*atan((sin(((4+(cos(atan(acos(y)))+(((1-3)-(1-5))-(cos(3)/atan(2)))))-x))*sqrt(acos(sin(cos((sqrt((4^y))*(sin(4)+asin(y)))))))))))))+(acos(atan(cos(((acos(3)+(exp(asin(tan(1)))+4))-x))))-(cos(sqrt(2))^((exp(atan((tan(4)^(atan((y*x))+tan(5)))))-acos(3))*exp(sqrt(4)))))))))))))-sqrt((sin(asin(atan((cos(acos(tan(tan(sqrt(((1+(acos(exp(x))/((4+atan(acos(((5-(x-x))-3))))^2)))+x))))))-y))))*acos(atan(atan((((x+((((x/sqrt((atan(ln(x))-((sqrt((3-tan(atan(atan(y)))))+x)*5))))+atan(((cos((acos(sqrt(atan((exp(3)+(y-4)))))/5))-2)-(acos((((((exp(2)-(y/4))-ln((x+x)))^(3*y))-(sin((tan(3)^(x*x)))+((asin(y)*(y/x))*(atan(y)-(x+5)))))-x))-(5*tan((asin(((tan(5)+acos(3))-(y^(2-5))))/cos(asin((3+tan(y)))))))))))*sqrt(4))-2))-x)+exp(2)))))))))^sin((ln(exp(y))+asin(sin((acos(5)+((acos((1^tan(y)))-cos(atan(acos(atan(y)))))+ln(((ln((1+tan(x)))+(ln(2)+cos((sqrt((y*((cos(atan(exp(4)))-(((atan((cos(y)+(y+exp(2))))+5)-3)-(x+5)))+sin(asin(sqrt(y))))))+(acos(exp(tan(sin(atan((tan(x)*(4+1)))))))-5)))))-(x-exp((((((atan((asin(x)-(cos(asin(((1*acos(y))+(ln(3)^5))))+tan(ln(((atan(2)+(1+y))/(3+atan(y))))))))/(acos(asin(acos(exp(5))))-2))/4)+((ln(atan(x))-(cos((sqrt(((sqrt(cos(2))*acos((2/x)))*acos(sin((2+4)))))*((((y+(4*2))^(sqrt(1)-y))-5)^((((y*x)-y)-((x*y)+(x+1)))-tan((sin(x)+sin(y)))))))-acos(1)))/sin(atan((cos((x*sqrt((atan((y-y) ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-08985541bd8b> in <module>()
#       1 gt = generate_tree(50)
# ----> 2 gt.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      61             self.left.print_expression()
#      62             print(self.value, end = '')
# ---> 63             self.right.print_expression()
#      64             print(')', end = '')
#      65         elif self.value in name_functions:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      59         if self.value in name_opers:
#      60             print('(', end = '')
# ---> 61             self.left.print_expression()
#      62             print(self.value, end = '')
#      63             self.right.print_expression()
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      65         elif self.value in name_functions:
#      66             print(self.value + '(', end = '')
# ---> 67             self.left.print_expression()
#      68             print(')', end = '')
#      69         elif self.value in variance:
#
# <ipython-input-11-f2a4d8f141a6> in print_expression(self)
#      66             print(self.value + '(', end = '')
#      67             self.left.print_expression()
# ---> 68             print(')', end = '')
#      69         elif self.value in variance:
#      70             print(self.value, end = '')
#
# /home/danil/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     358                     self.flush()
#     359             else:
# --> 360                 self._schedule_flush()
#     361
#     362     def writelines(self, sequence):
#
# /home/danil/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in _schedule_flush(self)
#     300         call this on write, to indicate that flush should be called soon.
#     301         """
# --> 302         if self._flush_pending:
#     303             return
#     304         self._flush_pending = True
#
# KeyboardInterrupt:

# %%
evaluate(gt, 1, 2)
# Out:
# 0.9092974268256817

# %%
pt = build_parse_tree("( ( 1 + 3 ) + ( 5 + 5 )")

# %%
pt.print_tree(4)
# Out:
#         +
#
#     +    +
#
#   1  3  5  5
